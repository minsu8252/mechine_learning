# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('h3')
for item in items :
    print(item.get_text())
# Out:
# 나만의 엣지있는 블로그 사이트 만들기
# 당신의 커리어에 파이썬을 입히세요! 자신만의 자동 프로그램까지 가져가는 특별한 강의

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('html head h1')
for item in items :
    print(item.get_text())

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content,'html.parser')

#selct_one 사용시 1개만 return함
items = soup.select_one('.course')
for item in items :
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#hobby_course_list > li:nth-child(1) > a')
for item in items :
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#popular_srch_lst span.txt > a')
for index, item in enumerate(items) :
    print(str(index +1) + '.', item.get_text())
# Out:
# 1. 어버이날 용돈박스
# 2. 면도기
# 3. 카네이션
# 4. 어버이날 선물
# 5. 크록스 키즈
# 6. 닌텐도 스위치
# 7. 마스크
# 8. 크록스
# 9. 에어팟 프로
# 10. 어버이날 카네이션

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#productListArea > ul p > a')
for index, item in enumerate(items) :
    print(str(index +1) + '.', item.get_text())
# Out:
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
# 11. 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 12. 나이키 기능성 드라이핏 반팔티 레전드 718...
# 13. 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 14. 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 15. 아디다스 오버핏 데일리 바람막이 우븐소재...
# 16. 지오다노 여 나일론 조거팬츠 411522
# 17. 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 18. 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 19. 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 20. 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 21. 아노락 바람막이 후드집업 반바지 트레이닝...
# 22. 지오다노 지오다노 여 레인코트 371513
# 23. 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 24. 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 25. 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 26. SOUP 기본 린넨 자켓 SW5JK80
# 27. 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 28. 이경희 란제리 레이스 슬립 가운세트
# 29. 나이키 스우시 반팔티 827021-100
# 30. 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# ...

# %%
import requests
from bs4 import BeautifulSoup
site_list= ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000','https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003','https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000004']
for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    items = soup.select('#productListArea > ul p > a')
    print(site)
    for index, item in enumerate(items) :
        print(str(index +1) + '.', item.get_text())
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
# 11. 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 12. 나이키 기능성 드라이핏 반팔티 레전드 718...
# 13. 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 14. 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 15. 아디다스 오버핏 데일리 바람막이 우븐소재...
# 16. 지오다노 여 나일론 조거팬츠 411522
# 17. 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 18. 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 19. 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 20. 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 21. 아노락 바람막이 후드집업 반바지 트레이닝...
# 22. 지오다노 지오다노 여 레인코트 371513
# 23. 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 24. 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 25. 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 26. SOUP 기본 린넨 자켓 SW5JK80
# 27. 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 28. 이경희 란제리 레이스 슬립 가운세트
# ...

# %%
import requests
from bs4 import BeautifulSoup

site_list= {'패션의류':'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000', '디지털/가전':'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003','가구/인테리어':'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000004'}
for name, site in site_list.items():
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    items = soup.select('#productListArea > ul p > a')
    print(name)
    for index, item in enumerate(items) :
        print(str(index +1) + '.', item.get_text())
# Out:
# 패션의류
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
# 11. 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 12. 나이키 기능성 드라이핏 반팔티 레전드 718...
# 13. 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 14. 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 15. 아디다스 오버핏 데일리 바람막이 우븐소재...
# 16. 지오다노 여 나일론 조거팬츠 411522
# 17. 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 18. 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 19. 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 20. 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 21. 아노락 바람막이 후드집업 반바지 트레이닝...
# 22. 지오다노 지오다노 여 레인코트 371513
# 23. 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 24. 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 25. 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 26. 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 27. SOUP 기본 린넨 자켓 SW5JK80
# 28. 이경희 란제리 레이스 슬립 가운세트
# 29. 나이키 스우시 반팔티 827021-100
# 30. 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# ...

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#popularItemList a')
for index, item in enumerate(items) :
    print(str(index +1) + '.', item.get_text())
# Out:
# 1. 삼성중공업
# 2. HMM
# 3. 삼성전자
# 4. 박셀바이오
# 5. 셀트리온
# 6. SK이노베이션
# 7. 카카오
# 8. 금호석유
# 9. SK하이닉스
# 10. 텔레칩스

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.rgt > ul.lst_major > li')

for index, item in enumerate(items) :
    
    print(str(index +1) + '.',item.find('a').get_text(), "현재지수:", item.find('span').get_text(), item.find('em').get_text())
# Out:
# 1. 다우산업 현재지수: 34,230.34 상승
# 2.  나스닥 현재지수: 13,582.43 하락
# 3.  홍콩H 현재지수: 10,802.15 상승
# 4.  상해종합 현재지수: 3,446.86 하락
# 5.  니케이225 현재지수: 29,328.60 상승

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.rgt > ul.lst_major > li')

for item in items :
    print(item.find('a').get_text(), "현재지수:", item.find('span').get_text())
# Out:
# 다우산업 현재지수: 34,230.34
#  나스닥 현재지수: 13,582.43
#  홍콩H 현재지수: 10,802.15
#  상해종합 현재지수: 3,446.86
#  니케이225 현재지수: 29,325.29

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

res = urlopen('https://davelee-fun.github.io/')
soup = BeautifulSoup(res, 'html.parser')

data = soup.select('h4')
for item in data :
    print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/xxx')
if res.status_code != 200 :
    print('페이지 없음')
    
else:
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text())
# Out:
# 페이지 없음

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# ...

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(5) :
    res = requests.get('https://www.clien.net/service/group/cm_all?&od=T31&category=0&po=' + str(page_num))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('#div_content > div.list_content div.list_title > a > span.subject_fixed')
    for item in data :
        print(item.get_text().strip())
# Out:
# 포토북 초회 포스터가 진짜 물량이 없었나봐요
# 어제 미장 보고 멘탈나갔다가 느낀점이 있어요
# 이오스가 오르네요.
# qnap qsync 프로그램을 지웠다가 다시 설치했는데 동기화 폴더를 설정 못합니다.
# 뽀삐가 힘을 내고 있군요🎊
# 종려 치확치피 세팅 질문…
# 6+ 사재 배터리도 괜찮을까요?
# 타이어 교체할때 순정으로 해야하나요?
# 28c 클린처 타이어 판매합니다.
# 애플티비 블루투스 스피커
# CJ ENM 드디어 플러스네요
# 오늘 박셀바이오 정리했습니다.
# HMM 잘 버티고 있습니다
# ssd 추천부탁드려요!
# 코인판 부러운점..
# 현기 2.5T, 3.5T용 순정 엔진오일 재고가 부족한가봅니다
# 교통사고 대인접수 관련하여 질문드립니다.
# 아파트 주차장 출입이 rf카드 이신분 계신가요?
# 오늘 아침 출근길에 스타리아 봤습니다.
# 피렐리 클린처 타이어 약하네요.
# 타이어랑 플러그 갈아줬습니다ㅎㅎ 질문!
# 저는 저만 믿고 갑니다 공매도 ..까!
# 포르자 모터스포츠도 재미있네요.
# 애플케어 플러스나 통신사 보험 사용하시나요?
# [COWAY x BTS] 코웨이 아이콘 정수기 Making film
# [HYBE INSIGHT] EXPERIENCE MUSIC - BTS
# 나에게 맞는 키보드 사이즈 찾기
# [단독]삼성·SK하이닉스·마이크론, 'D램 담합' 혐의로 피소
# 엔진 피스톤 겉부분이 녹았다면 무엇이 문제일까요?
# #COINKO 코인코 5월 6일 코인일정
# 포르쉐가 드림카가 된 순간
# 외국산 자동차가 참 많이 팔리네요
# 패러럴즈 문의 드려요
# 주린이 퀀트 매수 했네요 ㄷㄷㄷ
# 키보드 모양이 갑자기 바꼈습니다
# 그랜저IG 뒷바퀴 서스펜션 질문
# 고민 중인 기변 추천 부탁드려도 될까요?
# 활성산소에 대해 궁금합니다.
# 실적좋은데 공매때렸던 아저씨들
# 아이폰간 원격제어 방법 있을까요?
# IT관련학과이고 개발직 체험중인데 너무 힘드네요 ㅜㅜ
# 아반떼hd 수리.
# ...

# %% [markdown]
# 크롤링 해서 엑셀파일로 데이터 저장

# %%
import openpyxl

def write_excel_template(filename, sheetname, listdata) :
 
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
       #너비만 조절가능
    excel_sheet.column_dimensions['A'].width = 100
    excel_sheet.column_dimensions['B'].width = 20
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in listdata :
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
import requests
from bs4 import BeautifulSoup

product_lists = list()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('div.card')
    for item in data:
        product_name = item.select_one('div.card-body h4.card-text')
        product_date = item.select_one('div.wrapfooter span.post-date')
        product_info = [product_name.get_text().strip(), product_date.get_text()]
            #append() 데이터를 넣는 함수
        product_lists.append(product_info)

# %%
write_excel_template('tmp.xlsx', '상품정보', product_lists)
